# %%
import aplot
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots(1,2)

x = np.linspace(1,100, 100)
y = np.sin(x)

aplot.plot_z_1d(ax, x, y)
# Out:
# array([<Axes: title={'center': 'Amplitude'}>,
#        <Axes: title={'center': 'Phase'}>], dtype=object)
